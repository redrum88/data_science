# %% [markdown]
# <a href="https://colab.research.google.com/github/redrum88/data_science/blob/main/world_universities_ranking_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # World University Ranking 2023
# About Dataset
#
# World University Rankings 2023 is based upon 1,799 universities across 104 countries and regions based on many (at least 13) performance indicators that measure teaching, research, knowledge transfer, and international outlook. Data was collected from over 2,500 institutions, including survey responses from 40,000 scholars and analysis of over 121 million citations in 15.5 million research publications. The US has the most institutions overall and in the top 200, but China has overtaken Australia for the fourth-highest number of institutions in the top 200. The University of Oxford is ranked first for this year, while the highest new entry is Italy's Humanitas University.
#
# https://www.kaggle.com/datasets/tariqbashir/world-university-ranking-2023
#
# >**Note:** Dataset used for this notebook is edited. Merged odd and even rows from original csv.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn

# %%
df = pd.read_csv("https://raw.githubusercontent.com/redrum88/data_science/main/data/world_universities_ranking_2023_edited.csv")
df.head()
# Out:
#    Unnamed: 0      Rank                                   Name  \
# 0           0  Reporter                       Zarqa University
# 1           1  Reporter                    Ziauddin University
# 2           2  Reporter  Zhytomyr Polytechnic State University
# 3           3  Reporter    Yusuf Maitama Sule University, Kano
# 4           4  Reporter                York St John University
#
#   No. of FTE Students  No. of students per staff International Students  \
# 0               5,768                       18.1                    32%
# 1               4,906                        8.8                     1%
# 2               3,869                       15.4                     1%
# 3              12,880                       33.0                     0%
# 4               6,315                       18.6                    12%
#
#   Female:Male Ratio  Country/Region
# 0          47:53:00          Jordan
# 1          63:37:00        Pakistan
# 2           34 : 66         Ukraine
# 3          48:52:00         Nigeria
# 4          65:35:00  United Kingdom

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# Rank                         1077
# Name                            0
# No. of FTE Students          1077
# No. of students per staff    1078
# International Students       1077
# Female:Male Ratio            1129
# Country/Region                  0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# Rank                         0
# Name                         0
# No. of FTE Students          0
# No. of students per staff    0
# International Students       0
# Female:Male Ratio            0
# Country/Region               0
# dtype: int64

# %%
df_sorted = df.sort_values(by=['No. of FTE Students'], ascending=False)
df_top20 = df_sorted.head(20)
plt.figure(figsize=(12, 7))
plt.barh(df_top20['Name'], df_top20['No. of FTE Students'])
plt.xlabel('Number of FTE Students')
plt.ylabel('University Name')
plt.title('Top 20 Universities by Number of Students')
plt.show();
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
